# %%
from skimage.color import rgb2gray, rgb2lab, deltaE_cie76
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy import ndimage
from sklearn.cluster import KMeans
from collections import Counter

# %%
lastYearImg = [
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_01_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_02_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_03_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_04_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_05_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_06_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_07_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_08_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_09_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_10_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_11_01.jpg', 
                '../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_12_01.jpg',
              ]

# %%
# make ground mask based on Feb-Mar snow
imgFeb = cv2.imread('../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_02_01.jpg')
imgMar = cv2.imread('../data_raw/HARV/NEON.D01.HARV.DP1.00042_2021_03_01.jpg')
imgFeb = cv2.cvtColor(imgFeb, cv2.COLOR_BGR2RGB)
imgMar = cv2.cvtColor(imgMar, cv2.COLOR_BGR2RGB)
hsv_imgFeb = cv2.cvtColor(imgFeb, cv2.COLOR_RGB2HSV)
hsv_imgMar = cv2.cvtColor(imgMar, cv2.COLOR_RGB2HSV)
maskFeb = cv2.inRange(hsv_imgFeb, (0,0,80), (172,111,255))
maskMar = cv2.inRange(hsv_imgMar, (0,0,80), (172,111,255))
mask = cv2.bitwise_or(maskFeb, maskFeb, mask=maskMar)
plt.imshow(mask, cmap="gray")
plt.show()

# %% [markdown]
# ## Calculate greeness and redness overtime

# %%
green_over_time = []
red_over_time = []


for img_name in lastYearImg:
    img = cv2.imread(img_name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # display original image
    plt.imshow(img)
    plt.show()
    print("ground")
    
    #display original image with white mask applied
    result = cv2.bitwise_and(img, img, mask = mask)
    plt.imshow(result)
    plt.show()
                             
    print("green in ground")
    #create a range for greeness (HSV values)
    greenness = cv2.inRange(result, (20, 0, 0), (74, 255,255))
    #apply green mask to the image with white mask
    after_green_result = cv2.bitwise_and(result, result, mask = greenness)
    #display the image with green mask apply
    plt.imshow(after_green_result)
    plt.show()
    h, w = img.shape[:2]
    # find g/g+r+b (gcc value)
    red = np.sum(after_green_result[:,:,0]) #total red
    green = np.sum(after_green_result[:,:,1]) #total green
    blue = np.sum(after_green_result[:,:,2]) #total blue
    
    green_over_time.append(green/(green+red+blue))
    red_over_time.append(red/(red+green+blue))
    
    ##############
    
    #green_over_time.append(np.count_nonzero(after_green_result)/(h*w))

print(over_time)
# Out:
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ground
# green in ground
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6352/3868216849.py in <module>
#      37     #green_over_time.append(np.count_nonzero(after_green_result)/(h*w))
#      38
# ---> 39 print(over_time)
#      40
#      41
#
# NameError: name 'over_time' is not defined

# %%
#print g/g+r+b plot
plt.title("GCC over time")
plt.xlabel("month")
plt.ylabel("gcc value")
plt.plot(np.arange(1,13), green_over_time, color="green")
plt.plot(np.arange(1,13), red_over_time, color="red")
plt.show()
